# %% [markdown]
# # Anti-Diabetes Medications Data Extraction and Refinement
#
# This sheet covers the data process on preparing data target of anti-diabetes medicine products.
# The process includes data extraction, data filtering and grouping, cleaning, and combination.

# %% [markdown]
# ## Data Extraction from FDA USA Commerical Product Database
# USA commerical product databsase can be fetched at https://www.accessdata.fda.gov/cder/ndcxls.zip

# %%
import requests
import zipfile
import pandas as pd

# %%
#NDC databse file from FDA (covers all current commerical USA )
url = "https://www.accessdata.fda.gov/cder/ndcxls.zip"

# %%
#Download folder of files
response = requests.get(url)
if response.status_code == 200:
    with open("ndcxls.zip", "wb") as file:
        file.write(response.content)
    print("Downloaded successfully.")
else:
    print("Failed to download. Status code:", response.status_code)
# Out:
# Downloaded successfully.

# %%
#Unzip folder
extract_dir = "extracted_files"

with zipfile.ZipFile("ndcxls.zip", 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# %%
#Load files 
product_filename = "product.xls"
package_filename = "package.xls"

#one challenge here is two xls file actually are in a form of txt and both of them do not support utf-8 coding 
product_df = pd.read_csv(f"{extract_dir}/{product_filename}",delimiter='\t',encoding='latin1')
package_df = pd.read_csv(f"{extract_dir}/{package_filename}",delimiter='\t',encoding='latin1')

# %% [markdown]
# ### product_df
# product_df contains all current active USA pharmaceutical products, with attributes fields to indicate product information including dosage, molecule name(substance), router, trade label(Proprietary name) and etc.
# We are going to use the field of PHARM_CLASSES to filter in anti-diabetes products and productID to map package NDC with the file of package_df.

# %%
product_df.head(5)
# Out:
#                                         PRODUCTID PRODUCTNDC  \
# 0  0002-0213_458ef2aa-cd5f-48bc-8829-82420cfed33b  0002-0213
# 1  0002-0800_dec32ead-837e-4331-ab55-f3bbccea5b38  0002-0800
# 2  0002-1152_a820004b-8342-4e58-b733-2d97445b2f5e  0002-1152
# 3  0002-1200_7832a4ce-bb0e-4753-a72c-a5bc9621f08c  0002-1200
# 4  0002-1210_d03b2693-0231-4df4-a037-63017a42e85a  0002-1210
#
#            PRODUCTTYPENAME  PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 0           HUMAN OTC DRUG          Humulin                     R
# 1           HUMAN OTC DRUG  Sterile Diluent                   NaN
# 2  HUMAN PRESCRIPTION DRUG         MOUNJARO                   NaN
# 3  HUMAN PRESCRIPTION DRUG           Amyvid                   NaN
# 4  HUMAN PRESCRIPTION DRUG           TAUVID                   NaN
#
#   NONPROPRIETARYNAME       DOSAGEFORMNAME     ROUTENAME  STARTMARKETINGDATE  \
# 0      Insulin human  INJECTION, SOLUTION    PARENTERAL            19830627
# 1            diluent  INJECTION, SOLUTION  SUBCUTANEOUS            19870710
# 2        tirzepatide  INJECTION, SOLUTION  SUBCUTANEOUS            20230728
# 3   Florbetapir F 18  INJECTION, SOLUTION   INTRAVENOUS            20120601
# 4  Flortaucipir F-18  INJECTION, SOLUTION   INTRAVENOUS            20200528
#
#    ENDMARKETINGDATE MARKETINGCATEGORYNAME APPLICATIONNUMBER  \
# 0               NaN                   BLA         BLA018780
# 1               NaN                   BLA         BLA018781
# 2               NaN                   NDA         NDA215866
# 3               NaN                   NDA         NDA202008
# 4               NaN                   NDA         NDA212123
#
#              LABELERNAME      SUBSTANCENAME ACTIVE_NUMERATOR_STRENGTH  \
# 0  Eli Lilly and Company      INSULIN HUMAN                       100
# 1  Eli Lilly and Company              WATER                         1
# 2  Eli Lilly and Company        TIRZEPATIDE                       2.5
# 3  Eli Lilly and Company   FLORBETAPIR F-18                        51
# 4  Eli Lilly and Company  FLORTAUCIPIR F-18                        51
#
#   ACTIVE_INGRED_UNIT                                      PHARM_CLASSES  \
# 0            [iU]/mL                        Insulin [CS], Insulin [EPC]
# 1              mL/mL                                                NaN
# 2            mg/.5mL  G-Protein-linked Receptor Interactions [MoA], ...
# 3             mCi/mL  Positron Emitting Activity [MoA], Radioactive ...
# 4             mCi/mL                                                NaN
#
#   DEASCHEDULE NDC_EXCLUDE_FLAG  LISTING_RECORD_CERTIFIED_THROUGH
# 0         NaN                N                        20241231.0
# 1         NaN                N                        20241231.0
# 2         NaN                N                        20241231.0
# 3         NaN                N                        20241231.0
# 4         NaN                N                        20231231.0

# %% [markdown]
# ### package_df
# Package_df contains product package NDC which is a 11-digit unique identify key. The key will be used to map for drug utilization file.

# %%
package_df.head(5)
# Out:
#                                         PRODUCTID PRODUCTNDC NDCPACKAGECODE  \
# 0  0002-0213_458ef2aa-cd5f-48bc-8829-82420cfed33b  0002-0213   0002-0213-01
# 1  0002-0800_dec32ead-837e-4331-ab55-f3bbccea5b38  0002-0800   0002-0800-01
# 2  0002-1152_a820004b-8342-4e58-b733-2d97445b2f5e  0002-1152   0002-1152-01
# 3  0002-1200_7832a4ce-bb0e-4753-a72c-a5bc9621f08c  0002-1200   0002-1200-48
# 4  0002-1200_7832a4ce-bb0e-4753-a72c-a5bc9621f08c  0002-1200   0002-1200-50
#
#                                   PACKAGEDESCRIPTION  STARTMARKETINGDATE  \
# 0  1 VIAL, MULTI-DOSE in 1 CARTON (0002-0213-01) ...            20230620
# 1  1 VIAL in 1 CARTON (0002-0800-01)  / 10 mL in ...            19870710
# 2  1 VIAL, SINGLE-DOSE in 1 CARTON (0002-1152-01)...            20230728
# 3  1 VIAL, MULTI-DOSE in 1 CAN (0002-1200-48)  / ...            20230522
# 4  1 VIAL, MULTI-DOSE in 1 CAN (0002-1200-50)  / ...            20120601
#
#    ENDMARKETINGDATE NDC_EXCLUDE_FLAG SAMPLE_PACKAGE
# 0               NaN                N              N
# 1               NaN                N              N
# 2               NaN                N              N
# 3               NaN                N              N
# 4               NaN                N              N

# %% [markdown]
# ## Anti-diabetes medication group
# Referenced by this web, we can categorize anti-diabetes medicines into 10 groups
# https://www.healthline.com/health/diabetes/medications-list

# %% [markdown]
# ### Insulin
# Insulin is the most common type of medication used in type 1 diabetes treatment.
# There are more than 20 types sold in the United States.
# The goal of treatment is to replace the insulin that your pancreas can’t make.
# Some people with type 2 diabetes may also need to take insulin. The same types of insulin used to treat type 1 diabetes can also treat type 2 diabetes.

# %%
Insulin=product_df[product_df['PHARM_CLASSES'].str.contains('Insulin', case=False, na=False)]
Insulin.head(5)
# Out:
#                                          PRODUCTID PRODUCTNDC  \
# 0   0002-0213_458ef2aa-cd5f-48bc-8829-82420cfed33b  0002-0213
# 2   0002-1152_a820004b-8342-4e58-b733-2d97445b2f5e  0002-1152
# 6   0002-1243_a820004b-8342-4e58-b733-2d97445b2f5e  0002-1243
# 11  0002-1457_a820004b-8342-4e58-b733-2d97445b2f5e  0002-1457
# 12  0002-1460_a820004b-8342-4e58-b733-2d97445b2f5e  0002-1460
#
#             PRODUCTTYPENAME PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 0            HUMAN OTC DRUG         Humulin                     R
# 2   HUMAN PRESCRIPTION DRUG        MOUNJARO                   NaN
# 6   HUMAN PRESCRIPTION DRUG        MOUNJARO                   NaN
# 11  HUMAN PRESCRIPTION DRUG        MOUNJARO                   NaN
# 12  HUMAN PRESCRIPTION DRUG        MOUNJARO                   NaN
#
#    NONPROPRIETARYNAME       DOSAGEFORMNAME     ROUTENAME  STARTMARKETINGDATE  \
# 0       Insulin human  INJECTION, SOLUTION    PARENTERAL            19830627
# 2         tirzepatide  INJECTION, SOLUTION  SUBCUTANEOUS            20230728
# 6         tirzepatide  INJECTION, SOLUTION  SUBCUTANEOUS            20230728
# 11        tirzepatide  INJECTION, SOLUTION  SUBCUTANEOUS            20220513
# 12        tirzepatide  INJECTION, SOLUTION  SUBCUTANEOUS            20220513
#
#     ENDMARKETINGDATE MARKETINGCATEGORYNAME APPLICATIONNUMBER  \
# 0                NaN                   BLA         BLA018780
# 2                NaN                   NDA         NDA215866
# 6                NaN                   NDA         NDA215866
# 11               NaN                   NDA         NDA215866
# 12               NaN                   NDA         NDA215866
#
#               LABELERNAME  SUBSTANCENAME ACTIVE_NUMERATOR_STRENGTH  \
# 0   Eli Lilly and Company  INSULIN HUMAN                       100
# 2   Eli Lilly and Company    TIRZEPATIDE                       2.5
# 6   Eli Lilly and Company    TIRZEPATIDE                         5
# 11  Eli Lilly and Company    TIRZEPATIDE                        15
# 12  Eli Lilly and Company    TIRZEPATIDE                      12.5
#
#    ACTIVE_INGRED_UNIT                                      PHARM_CLASSES  \
# 0             [iU]/mL                        Insulin [CS], Insulin [EPC]
# 2             mg/.5mL  G-Protein-linked Receptor Interactions [MoA], ...
# 6             mg/.5mL  G-Protein-linked Receptor Interactions [MoA], ...
# 11            mg/.5mL  G-Protein-linked Receptor Interactions [MoA], ...
# 12            mg/.5mL  G-Protein-linked Receptor Interactions [MoA], ...
#
#    DEASCHEDULE NDC_EXCLUDE_FLAG  LISTING_RECORD_CERTIFIED_THROUGH
# 0          NaN                N                        20241231.0
# 2          NaN                N                        20241231.0
# 6          NaN                N                        20241231.0
# 11         NaN                N                        20241231.0
# 12         NaN                N                        20241231.0

# %% [markdown]
# ### Alpha-glucosidase inhibitors
# These medications help your body break down starchy foods and table sugar. This effect lowers your blood sugar levels.
# When taken as prescribed, these medications won’t cause hypoglycemia (low blood sugar). However, your risk of hypoglycemia may be greater if you take them with other types of diabetes medications.

# %%
Alpha_G_INHB=product_df[product_df['PHARM_CLASSES'].str.contains('alpha Glucosidase Inhibitors', case=False, na=False)]
Alpha_G_INHB.head(5)
# Out:
#                                             PRODUCTID PRODUCTNDC  \
# 794    0054-0140_68881739-6edb-4c67-be06-14953f60a146  0054-0140
# 795    0054-0141_68881739-6edb-4c67-be06-14953f60a146  0054-0141
# 796    0054-0142_68881739-6edb-4c67-be06-14953f60a146  0054-0142
# 19263  23155-147_84ff1519-f0a6-4d8f-afd3-bce6f78813aa  23155-147
# 19264  23155-148_84ff1519-f0a6-4d8f-afd3-bce6f78813aa  23155-148
#
#                PRODUCTTYPENAME PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 794    HUMAN PRESCRIPTION DRUG        Acarbose                   NaN
# 795    HUMAN PRESCRIPTION DRUG        Acarbose                   NaN
# 796    HUMAN PRESCRIPTION DRUG        Acarbose                   NaN
# 19263  HUMAN PRESCRIPTION DRUG        Acarbose                   NaN
# 19264  HUMAN PRESCRIPTION DRUG        Acarbose                   NaN
#
#       NONPROPRIETARYNAME DOSAGEFORMNAME ROUTENAME  STARTMARKETINGDATE  \
# 794             Acarbose         TABLET      ORAL            20080507
# 795             Acarbose         TABLET      ORAL            20080507
# 796             Acarbose         TABLET      ORAL            20080507
# 19263           Acarbose         TABLET      ORAL            20210416
# 19264           Acarbose         TABLET      ORAL            20210416
#
#        ENDMARKETINGDATE MARKETINGCATEGORYNAME APPLICATIONNUMBER  \
# 794                 NaN                  ANDA        ANDA078470
# 795                 NaN                  ANDA        ANDA078470
# 796                 NaN                  ANDA        ANDA078470
# 19263               NaN                  ANDA        ANDA202271
# 19264               NaN                  ANDA        ANDA202271
#
#                                              LABELERNAME SUBSTANCENAME  \
# 794                       Hikma Pharmaceuticals USA Inc.      ACARBOSE
# 795                       Hikma Pharmaceuticals USA Inc.      ACARBOSE
# 796                       Hikma Pharmaceuticals USA Inc.      ACARBOSE
# 19263  Heritage Pharmaceuticals Inc. d/b/a Avet Pharm...      ACARBOSE
# 19264  Heritage Pharmaceuticals Inc. d/b/a Avet Pharm...      ACARBOSE
#
#       ACTIVE_NUMERATOR_STRENGTH ACTIVE_INGRED_UNIT  \
# 794                          25               mg/1
# 795                          50               mg/1
# 796                         100               mg/1
# 19263                        25               mg/1
# 19264                        50               mg/1
#
#                                            PHARM_CLASSES DEASCHEDULE  \
# 794    alpha Glucosidase Inhibitors [MoA], alpha-Gluc...         NaN
# 795    alpha Glucosidase Inhibitors [MoA], alpha-Gluc...         NaN
# 796    alpha Glucosidase Inhibitors [MoA], alpha-Gluc...         NaN
# 19263  alpha Glucosidase Inhibitors [MoA], alpha-Gluc...         NaN
# 19264  alpha Glucosidase Inhibitors [MoA], alpha-Gluc...         NaN
#
#       NDC_EXCLUDE_FLAG  LISTING_RECORD_CERTIFIED_THROUGH
# 794                  N                        20241231.0
# 795                  N                        20241231.0
# 796                  N                        20241231.0
# 19263                N                        20241231.0
# 19264                N                        20241231.0

# %% [markdown]
# ### Thiazolidinediones
# Thiazolidinediones work by decreasing glucose in your liver. They also help your fat cells use insulin better by targeting insulin resistanceTrusted Source.

# %%
Thiazolidinedione= product_df[product_df['PHARM_CLASSES'].str.contains('Thiazolidinedione', case=False, na=False)]
Thiazolidinedione.head(5)
# Out:
#                                             PRODUCTID PRODUCTNDC  \
# 1928   0093-7271_b5d757a4-7f61-4f9d-bd2a-0ebf9892398d  0093-7271
# 1929   0093-7272_b5d757a4-7f61-4f9d-bd2a-0ebf9892398d  0093-7272
# 1930   0093-7273_b5d757a4-7f61-4f9d-bd2a-0ebf9892398d  0093-7273
# 10567  0781-5420_114a7af7-cc48-4535-8b56-589941e5f521  0781-5420
# 10568  0781-5421_114a7af7-cc48-4535-8b56-589941e5f521  0781-5421
#
#                PRODUCTTYPENAME PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 1928   HUMAN PRESCRIPTION DRUG    Pioglitazone                   NaN
# 1929   HUMAN PRESCRIPTION DRUG    Pioglitazone                   NaN
# 1930   HUMAN PRESCRIPTION DRUG    Pioglitazone                   NaN
# 10567  HUMAN PRESCRIPTION DRUG    Pioglitazone                   NaN
# 10568  HUMAN PRESCRIPTION DRUG    Pioglitazone                   NaN
#
#       NONPROPRIETARYNAME DOSAGEFORMNAME ROUTENAME  STARTMARKETINGDATE  \
# 1928        Pioglitazone         TABLET      ORAL            20150204
# 1929        Pioglitazone         TABLET      ORAL            20150204
# 1930        Pioglitazone         TABLET      ORAL            20150522
# 10567       pioglitazone         TABLET      ORAL            20130301
# 10568       pioglitazone         TABLET      ORAL            20130301
#
#        ENDMARKETINGDATE MARKETINGCATEGORYNAME APPLICATIONNUMBER  \
# 1928                NaN                  ANDA        ANDA077210
# 1929                NaN                  ANDA        ANDA077210
# 1930                NaN                  ANDA        ANDA077210
# 10567               NaN                  ANDA        ANDA078670
# 10568               NaN                  ANDA        ANDA078670
#
#                           LABELERNAME               SUBSTANCENAME  \
# 1928   Teva Pharmaceuticals USA, Inc.  PIOGLITAZONE HYDROCHLORIDE
# 1929   Teva Pharmaceuticals USA, Inc.  PIOGLITAZONE HYDROCHLORIDE
# 1930   Teva Pharmaceuticals USA, Inc.  PIOGLITAZONE HYDROCHLORIDE
# 10567                      Sandoz Inc  PIOGLITAZONE HYDROCHLORIDE
# 10568                      Sandoz Inc  PIOGLITAZONE HYDROCHLORIDE
#
#       ACTIVE_NUMERATOR_STRENGTH ACTIVE_INGRED_UNIT  \
# 1928                         15               mg/1
# 1929                         30               mg/1
# 1930                         45               mg/1
# 10567                        15               mg/1
# 10568                        30               mg/1
#
#                                            PHARM_CLASSES DEASCHEDULE  \
# 1928   PPAR alpha [CS], PPAR gamma [CS], Peroxisome P...         NaN
# 1929   PPAR alpha [CS], PPAR gamma [CS], Peroxisome P...         NaN
# 1930   PPAR alpha [CS], PPAR gamma [CS], Peroxisome P...         NaN
# 10567  PPAR alpha [CS], PPAR gamma [CS], Peroxisome P...         NaN
# 10568  PPAR alpha [CS], PPAR gamma [CS], Peroxisome P...         NaN
#
#       NDC_EXCLUDE_FLAG  LISTING_RECORD_CERTIFIED_THROUGH
# 1928                 N                        20231231.0
# 1929                 N                        20231231.0
# 1930                 N                        20231231.0
# 10567                N                        20231231.0
# 10568                N                        20231231.0

# %% [markdown]
# ### Biguanides
# Biguanides decrease how much glucose your liver makes. They also decrease how much glucose your intestines absorb, help your muscles absorb glucose, and make your body more sensitive to insulin.

# %%
Biguanides=product_df[product_df['PHARM_CLASSES'].str.contains('Biguanide', case=False, na=False)]
Biguanides.head(5)
# Out:
#                                           PRODUCTID PRODUCTNDC  \
# 179  0006-0078_40b87f24-8005-4ee7-b162-94690443fdb0  0006-0078
# 180  0006-0080_40b87f24-8005-4ee7-b162-94690443fdb0  0006-0080
# 181  0006-0081_40b87f24-8005-4ee7-b162-94690443fdb0  0006-0081
# 194  0006-0575_57ef5ead-02e0-417d-b21f-8e41ff34b53f  0006-0575
# 195  0006-0577_57ef5ead-02e0-417d-b21f-8e41ff34b53f  0006-0577
#
#              PRODUCTTYPENAME PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 179  HUMAN PRESCRIPTION DRUG         JANUMET                    XR
# 180  HUMAN PRESCRIPTION DRUG         JANUMET                    XR
# 181  HUMAN PRESCRIPTION DRUG         JANUMET                    XR
# 194  HUMAN PRESCRIPTION DRUG         JANUMET                   NaN
# 195  HUMAN PRESCRIPTION DRUG         JANUMET                   NaN
#
#                           NONPROPRIETARYNAME  \
# 179  sitagliptin and metformin hydrochloride
# 180  sitagliptin and metformin hydrochloride
# 181  sitagliptin and metformin hydrochloride
# 194  SITAGLIPTIN and METFORMIN HYDROCHLORIDE
# 195  SITAGLIPTIN and METFORMIN HYDROCHLORIDE
#
#                             DOSAGEFORMNAME ROUTENAME  STARTMARKETINGDATE  \
# 179  TABLET, FILM COATED, EXTENDED RELEASE      ORAL            20120202
# 180  TABLET, FILM COATED, EXTENDED RELEASE      ORAL            20120202
# 181  TABLET, FILM COATED, EXTENDED RELEASE      ORAL            20120202
# 194                    TABLET, FILM COATED      ORAL            20070330
# 195                    TABLET, FILM COATED      ORAL            20070330
#
#      ENDMARKETINGDATE MARKETINGCATEGORYNAME APPLICATIONNUMBER  \
# 179               NaN                   NDA         NDA202270
# 180               NaN                   NDA         NDA202270
# 181               NaN                   NDA         NDA202270
# 194               NaN                   NDA         NDA022044
# 195               NaN                   NDA         NDA022044
#
#                  LABELERNAME                                   SUBSTANCENAME  \
# 179  Merck Sharp & Dohme LLC  METFORMIN HYDROCHLORIDE; SITAGLIPTIN PHOSPHATE
# 180  Merck Sharp & Dohme LLC  METFORMIN HYDROCHLORIDE; SITAGLIPTIN PHOSPHATE
# 181  Merck Sharp & Dohme LLC  METFORMIN HYDROCHLORIDE; SITAGLIPTIN PHOSPHATE
# 194  Merck Sharp & Dohme LLC  METFORMIN HYDROCHLORIDE; SITAGLIPTIN PHOSPHATE
# 195  Merck Sharp & Dohme LLC  METFORMIN HYDROCHLORIDE; SITAGLIPTIN PHOSPHATE
#
#     ACTIVE_NUMERATOR_STRENGTH ACTIVE_INGRED_UNIT  \
# 179                   500; 50         mg/1; mg/1
# 180                  1000; 50         mg/1; mg/1
# 181                 1000; 100         mg/1; mg/1
# 194                   500; 50         mg/1; mg/1
# 195                  1000; 50         mg/1; mg/1
#
#                                          PHARM_CLASSES DEASCHEDULE  \
# 179  Biguanide [EPC], Biguanides [CS], Dipeptidyl P...         NaN
# 180  Biguanide [EPC], Biguanides [CS], Dipeptidyl P...         NaN
# 181  Biguanide [EPC], Biguanides [CS], Dipeptidyl P...         NaN
# 194  Biguanide [EPC], Biguanides [CS], Dipeptidyl P...         NaN
# 195  Biguanide [EPC], Biguanides [CS], Dipeptidyl P...         NaN
#
#     NDC_EXCLUDE_FLAG  LISTING_RECORD_CERTIFIED_THROUGH
# 179                N                        20241231.0
# 180                N                        20241231.0
# 181                N                        20241231.0
# 194                N                        20241231.0
# 195                N                        20241231.0

# %% [markdown]
# ### Sulfonylureas
# These are among the oldestTrusted Source diabetes drugs still used today. They work by stimulating the pancreas with the help of beta cells. This causes your body to make more insulin.

# %%
Sulfonylurea=product_df[product_df['PHARM_CLASSES'].str.contains('Sulfonylurea', case=False, na=False)]
Sulfonylurea.head(5)
# Out:
#                                           PRODUCTID PRODUCTNDC  \
# 327  0009-0341_555c58db-4984-40d4-9806-86655fade006  0009-0341
# 329  0009-0352_555c58db-4984-40d4-9806-86655fade006  0009-0352
# 356  0009-3449_555c58db-4984-40d4-9806-86655fade006  0009-3449
# 671  0049-0170_1fdfc3b7-b578-4c68-896e-b8cf38d10fa1  0049-0170
# 672  0049-0174_1fdfc3b7-b578-4c68-896e-b8cf38d10fa1  0049-0174
#
#              PRODUCTTYPENAME PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 327  HUMAN PRESCRIPTION DRUG         Glynase                   NaN
# 329  HUMAN PRESCRIPTION DRUG         Glynase                   NaN
# 356  HUMAN PRESCRIPTION DRUG         Glynase                   NaN
# 671  HUMAN PRESCRIPTION DRUG       Glucotrol                    XL
# 672  HUMAN PRESCRIPTION DRUG       Glucotrol                    XL
#
#     NONPROPRIETARYNAME            DOSAGEFORMNAME ROUTENAME  \
# 327          glyburide                    TABLET      ORAL
# 329          glyburide                    TABLET      ORAL
# 356          glyburide                    TABLET      ORAL
# 671          glipizide  TABLET, EXTENDED RELEASE      ORAL
# 672          glipizide  TABLET, EXTENDED RELEASE      ORAL
#
#      STARTMARKETINGDATE  ENDMARKETINGDATE MARKETINGCATEGORYNAME  \
# 327            19920304               NaN                   NDA
# 329            19920304               NaN                   NDA
# 356            19920304               NaN                   NDA
# 671            20130715               NaN                   NDA
# 672            20130509               NaN                   NDA
#
#     APPLICATIONNUMBER                     LABELERNAME SUBSTANCENAME  \
# 327         NDA020051  Pharmacia & Upjohn Company LLC     GLYBURIDE
# 329         NDA020051  Pharmacia & Upjohn Company LLC     GLYBURIDE
# 356         NDA020051  Pharmacia & Upjohn Company LLC     GLYBURIDE
# 671         NDA020329                          Roerig     GLIPIZIDE
# 672         NDA020329                          Roerig     GLIPIZIDE
#
#     ACTIVE_NUMERATOR_STRENGTH ACTIVE_INGRED_UNIT  \
# 327                       1.5               mg/1
# 329                         3               mg/1
# 356                         6               mg/1
# 671                       2.5               mg/1
# 672                         5               mg/1
#
#                                        PHARM_CLASSES DEASCHEDULE  \
# 327  Sulfonylurea Compounds [CS], Sulfonylurea [EPC]         NaN
# 329  Sulfonylurea Compounds [CS], Sulfonylurea [EPC]         NaN
# 356  Sulfonylurea Compounds [CS], Sulfonylurea [EPC]         NaN
# 671  Sulfonylurea Compounds [CS], Sulfonylurea [EPC]         NaN
# 672  Sulfonylurea Compounds [CS], Sulfonylurea [EPC]         NaN
#
#     NDC_EXCLUDE_FLAG  LISTING_RECORD_CERTIFIED_THROUGH
# 327                N                        20241231.0
# 329                N                        20241231.0
# 356                N                        20241231.0
# 671                N                        20241231.0
# 672                N                        20241231.0

# %% [markdown]
# ### Dopamine-2 agonist
# It’s unknown exactly how this drug treats type 2 diabetes. It may affect rhythms in your body and prevent insulin resistance. According to one 2015 reviewTrusted Source, dopamine-2 agonists may also improve other related health concerns, such as high cholesterol or weight management.

# %%
DA_2A=product_df[product_df['SUBSTANCENAME'].str.contains('BROMOCRIPTINE MESYLATE', case=False, na=False)]
DA_2A.head(5)
# Out:
#                                             PRODUCTID PRODUCTNDC  \
# 7323   0378-7096_caaa8c54-ee5c-47a9-8455-1f49fab45143  0378-7096
# 9314   0574-0106_4132274e-3abb-49b4-8d1b-3400a1df9daf  0574-0106
# 10563  0781-5325_ed58abc4-1571-46be-8190-29dcaed68fef  0781-5325
# 21384  30698-201_e66711ca-726a-4a85-b2fa-d5ccb85e1221  30698-201
# 21385  30698-202_e66711ca-726a-4a85-b2fa-d5ccb85e1221  30698-202
#
#                PRODUCTTYPENAME         PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 7323   HUMAN PRESCRIPTION DRUG  Bromocriptine Mesylate                   NaN
# 9314   HUMAN PRESCRIPTION DRUG  Bromocriptine mesylate                   NaN
# 10563  HUMAN PRESCRIPTION DRUG  Bromocriptine mesylate                   NaN
# 21384  HUMAN PRESCRIPTION DRUG                Parlodel                   NaN
# 21385  HUMAN PRESCRIPTION DRUG                Parlodel                   NaN
#
#            NONPROPRIETARYNAME           DOSAGEFORMNAME ROUTENAME  \
# 7323   bromocriptine mesylate                  CAPSULE      ORAL
# 9314   Bromocriptine mesylate                   TABLET      ORAL
# 10563  Bromocriptine mesylate                   TABLET      ORAL
# 21384  bromocriptine mesylate  CAPSULE, GELATIN COATED      ORAL
# 21385  bromocriptine mesylate                   TABLET      ORAL
#
#        STARTMARKETINGDATE  ENDMARKETINGDATE MARKETINGCATEGORYNAME  \
# 7323             20130617               NaN                  ANDA
# 9314             20140401               NaN                  ANDA
# 10563            19980113               NaN                  ANDA
# 21384            20140428               NaN                   NDA
# 21385            20140428               NaN                   NDA
#
#       APPLICATIONNUMBER                  LABELERNAME           SUBSTANCENAME  \
# 7323         ANDA077226   Mylan Pharmaceuticals Inc.  BROMOCRIPTINE MESYLATE
# 9314         ANDA077646               Padagis US LLC  BROMOCRIPTINE MESYLATE
# 10563        ANDA074631                   Sandoz Inc  BROMOCRIPTINE MESYLATE
# 21384         NDA017962  Validus Pharmaceuticals LLC  BROMOCRIPTINE MESYLATE
# 21385         NDA017962  Validus Pharmaceuticals LLC  BROMOCRIPTINE MESYLATE
#
#       ACTIVE_NUMERATOR_STRENGTH ACTIVE_INGRED_UNIT  \
# 7323                          5               mg/1
# 9314                        2.5               mg/1
# 10563                       2.5               mg/1
# 21384                         5               mg/1
# 21385                       2.5               mg/1
#
#                                 PHARM_CLASSES DEASCHEDULE NDC_EXCLUDE_FLAG  \
# 7323   Ergolines [CS], Ergot Derivative [EPC]         NaN                N
# 9314   Ergolines [CS], Ergot Derivative [EPC]         NaN                N
# 10563  Ergolines [CS], Ergot Derivative [EPC]         NaN                N
# 21384  Ergolines [CS], Ergot Derivative [EPC]         NaN                N
# 21385  Ergolines [CS], Ergot Derivative [EPC]         NaN                N
#
#        LISTING_RECORD_CERTIFIED_THROUGH
# 7323                         20231231.0
# 9314                         20231231.0
# 10563                        20231231.0
# 21384                        20241231.0
# 21385                        20241231.0

# %% [markdown]
# ### Sodium-glucose transporter (SGLT) 2 inhibitors
# Sodium-glucose transporter (SGLT) 2 inhibitors work by preventing the kidneys from holding on to glucose. Instead, your body gets rid of the glucose through your urine.

# %%
SGLT_2_INHB=product_df[product_df['PHARM_CLASSES'].str.contains('Sodium-Glucose Transporter 2 Inhibitors', case=False, na=False)]
SGLT_2_INHB.head(5)
# Out:
#                                            PRODUCTID PRODUCTNDC  \
# 5545  0310-6205_129852e5-b1f1-488e-99fe-aa8d0d4fd07a  0310-6205
# 5546  0310-6210_129852e5-b1f1-488e-99fe-aa8d0d4fd07a  0310-6210
# 5547  0310-6225_7d19a7d8-7419-4bf1-8462-52894fe73902  0310-6225
# 5548  0310-6250_7d19a7d8-7419-4bf1-8462-52894fe73902  0310-6250
# 5549  0310-6260_7d19a7d8-7419-4bf1-8462-52894fe73902  0310-6260
#
#               PRODUCTTYPENAME PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 5545  HUMAN PRESCRIPTION DRUG         FARXIGA                   NaN
# 5546  HUMAN PRESCRIPTION DRUG         FARXIGA                   NaN
# 5547  HUMAN PRESCRIPTION DRUG          XIGDUO                    XR
# 5548  HUMAN PRESCRIPTION DRUG          XIGDUO                    XR
# 5549  HUMAN PRESCRIPTION DRUG          XIGDUO                    XR
#
#                              NONPROPRIETARYNAME  \
# 5545                              DAPAGLIFLOZIN
# 5546                              DAPAGLIFLOZIN
# 5547  dapagliflozin and metformin hydrochloride
# 5548  dapagliflozin and metformin hydrochloride
# 5549  dapagliflozin and metformin hydrochloride
#
#                              DOSAGEFORMNAME ROUTENAME  STARTMARKETINGDATE  \
# 5545                    TABLET, FILM COATED      ORAL            20080114
# 5546                    TABLET, FILM COATED      ORAL            20080114
# 5547  TABLET, FILM COATED, EXTENDED RELEASE      ORAL            20141029
# 5548  TABLET, FILM COATED, EXTENDED RELEASE      ORAL            20141029
# 5549  TABLET, FILM COATED, EXTENDED RELEASE      ORAL            20141029
#
#       ENDMARKETINGDATE MARKETINGCATEGORYNAME APPLICATIONNUMBER  \
# 5545               NaN                   NDA         NDA202293
# 5546               NaN                   NDA         NDA202293
# 5547               NaN                   NDA         NDA205649
# 5548               NaN                   NDA         NDA205649
# 5549               NaN                   NDA         NDA205649
#
#                          LABELERNAME  \
# 5545  AstraZeneca Pharmaceuticals LP
# 5546  AstraZeneca Pharmaceuticals LP
# 5547  AstraZeneca Pharmaceuticals LP
# 5548  AstraZeneca Pharmaceuticals LP
# 5549  AstraZeneca Pharmaceuticals LP
#
#                                           SUBSTANCENAME  \
# 5545                          DAPAGLIFLOZIN PROPANEDIOL
# 5546                          DAPAGLIFLOZIN PROPANEDIOL
# 5547  DAPAGLIFLOZIN PROPANEDIOL; METFORMIN HYDROCHLO...
# 5548  DAPAGLIFLOZIN PROPANEDIOL; METFORMIN HYDROCHLO...
# 5549  DAPAGLIFLOZIN PROPANEDIOL; METFORMIN HYDROCHLO...
#
#      ACTIVE_NUMERATOR_STRENGTH ACTIVE_INGRED_UNIT  \
# 5545                         5               mg/1
# 5546                        10               mg/1
# 5547                 2.5; 1000         mg/1; mg/1
# 5548                    5; 500         mg/1; mg/1
# 5549                   5; 1000         mg/1; mg/1
#
#                                           PHARM_CLASSES DEASCHEDULE  \
# 5545  Sodium-Glucose Cotransporter 2 Inhibitor [EPC]...         NaN
# 5546  Sodium-Glucose Cotransporter 2 Inhibitor [EPC]...         NaN
# 5547  Biguanide [EPC], Biguanides [CS], Sodium-Gluco...         NaN
# 5548  Biguanide [EPC], Biguanides [CS], Sodium-Gluco...         NaN
# 5549  Biguanide [EPC], Biguanides [CS], Sodium-Gluco...         NaN
#
#      NDC_EXCLUDE_FLAG  LISTING_RECORD_CERTIFIED_THROUGH
# 5545                N                        20241231.0
# 5546                N                        20241231.0
# 5547                N                        20241231.0
# 5548                N                        20241231.0
# 5549                N                        20241231.0

# %% [markdown]
# ### Glucagon-like peptide-1 receptor agonists (GLP-1 receptor agonists)
# GLP-1 receptor agonists are similar to incretin and may be prescribed in addition to a diet and exercise plan to help promote better glycemic control.
#
# They increase how much insulin your body uses and the growth of pancreatic beta cells. They decrease your appetite and how much glucagon your body uses. They also slow stomach emptying, which may maximize nutrient absorption from the foods you eat while potentially helpingTrusted Source you maintain or lose weight.
#
# This the medicine group Elon is taking.

# %%
GLP_1_RA=product_df[product_df['PHARM_CLASSES'].str.contains('GLP-1 Receptor Agonist', case=False, na=False)]
GLP_1_RA.head(5)
# Out:
#                                          PRODUCTID PRODUCTNDC  \
# 2   0002-1152_a820004b-8342-4e58-b733-2d97445b2f5e  0002-1152
# 6   0002-1243_a820004b-8342-4e58-b733-2d97445b2f5e  0002-1243
# 7   0002-1433_e7c6d8de-a271-493d-8a2a-c9c08e8f92b8  0002-1433
# 8   0002-1434_e7c6d8de-a271-493d-8a2a-c9c08e8f92b8  0002-1434
# 11  0002-1457_a820004b-8342-4e58-b733-2d97445b2f5e  0002-1457
#
#             PRODUCTTYPENAME PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 2   HUMAN PRESCRIPTION DRUG        MOUNJARO                   NaN
# 6   HUMAN PRESCRIPTION DRUG        MOUNJARO                   NaN
# 7   HUMAN PRESCRIPTION DRUG       Trulicity                   NaN
# 8   HUMAN PRESCRIPTION DRUG       Trulicity                   NaN
# 11  HUMAN PRESCRIPTION DRUG        MOUNJARO                   NaN
#
#    NONPROPRIETARYNAME       DOSAGEFORMNAME     ROUTENAME  STARTMARKETINGDATE  \
# 2         tirzepatide  INJECTION, SOLUTION  SUBCUTANEOUS            20230728
# 6         tirzepatide  INJECTION, SOLUTION  SUBCUTANEOUS            20230728
# 7         Dulaglutide  INJECTION, SOLUTION  SUBCUTANEOUS            20140918
# 8         Dulaglutide  INJECTION, SOLUTION  SUBCUTANEOUS            20140918
# 11        tirzepatide  INJECTION, SOLUTION  SUBCUTANEOUS            20220513
#
#     ENDMARKETINGDATE MARKETINGCATEGORYNAME APPLICATIONNUMBER  \
# 2                NaN                   NDA         NDA215866
# 6                NaN                   NDA         NDA215866
# 7                NaN                   BLA         BLA125469
# 8                NaN                   BLA         BLA125469
# 11               NaN                   NDA         NDA215866
#
#               LABELERNAME SUBSTANCENAME ACTIVE_NUMERATOR_STRENGTH  \
# 2   Eli Lilly and Company   TIRZEPATIDE                       2.5
# 6   Eli Lilly and Company   TIRZEPATIDE                         5
# 7   Eli Lilly and Company   DULAGLUTIDE                       .75
# 8   Eli Lilly and Company   DULAGLUTIDE                       1.5
# 11  Eli Lilly and Company   TIRZEPATIDE                        15
#
#    ACTIVE_INGRED_UNIT                                      PHARM_CLASSES  \
# 2             mg/.5mL  G-Protein-linked Receptor Interactions [MoA], ...
# 6             mg/.5mL  G-Protein-linked Receptor Interactions [MoA], ...
# 7             mg/.5mL  GLP-1 Receptor Agonist [EPC], Glucagon-Like Pe...
# 8             mg/.5mL  GLP-1 Receptor Agonist [EPC], Glucagon-Like Pe...
# 11            mg/.5mL  G-Protein-linked Receptor Interactions [MoA], ...
#
#    DEASCHEDULE NDC_EXCLUDE_FLAG  LISTING_RECORD_CERTIFIED_THROUGH
# 2          NaN                N                        20241231.0
# 6          NaN                N                        20241231.0
# 7          NaN                N                        20241231.0
# 8          NaN                N                        20241231.0
# 11         NaN                N                        20241231.0

# %% [markdown]
# ### Glinide
# These medications help your body release insulin. However, they aren’t for everyone. In some cases, they may lower your blood sugar too much, especially if you haveTrusted Source advanced kidney disease.

# %%
Glinide=product_df[product_df['PHARM_CLASSES'].str.contains('Glinide', case=False, na=False)]
Glinide.head(5)
# Out:
#                                            PRODUCTID PRODUCTNDC  \
# 9329  0574-0240_d49adc4a-7bb7-4794-8355-210325b08ff5  0574-0240
# 9330  0574-0241_d49adc4a-7bb7-4794-8355-210325b08ff5  0574-0241
# 9331  0574-0242_d49adc4a-7bb7-4794-8355-210325b08ff5  0574-0242
# 9511  0591-3354_573675b0-8d66-4d58-85f2-428dda7c166c  0591-3354
# 9512  0591-3355_573675b0-8d66-4d58-85f2-428dda7c166c  0591-3355
#
#               PRODUCTTYPENAME PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 9329  HUMAN PRESCRIPTION DRUG     Repaglinide                   NaN
# 9330  HUMAN PRESCRIPTION DRUG     Repaglinide                   NaN
# 9331  HUMAN PRESCRIPTION DRUG     Repaglinide                   NaN
# 9511  HUMAN PRESCRIPTION DRUG     Nateglinide                   NaN
# 9512  HUMAN PRESCRIPTION DRUG     Nateglinide                   NaN
#
#      NONPROPRIETARYNAME DOSAGEFORMNAME ROUTENAME  STARTMARKETINGDATE  \
# 9329        REPAGLINIDE         TABLET      ORAL            20130809
# 9330        REPAGLINIDE         TABLET      ORAL            20140122
# 9331        REPAGLINIDE         TABLET      ORAL            20140122
# 9511        Nateglinide         TABLET      ORAL            20110518
# 9512        Nateglinide         TABLET      ORAL            20110518
#
#       ENDMARKETINGDATE MARKETINGCATEGORYNAME APPLICATIONNUMBER  \
# 9329               NaN                  ANDA        ANDA201189
# 9330        20250131.0                  ANDA        ANDA201189
# 9331        20240531.0                  ANDA        ANDA201189
# 9511               NaN                  ANDA        ANDA077462
# 9512               NaN                  ANDA        ANDA077462
#
#                LABELERNAME SUBSTANCENAME ACTIVE_NUMERATOR_STRENGTH  \
# 9329        Padagis US LLC   REPAGLINIDE                        .5
# 9330        Padagis US LLC   REPAGLINIDE                         1
# 9331        Padagis US LLC   REPAGLINIDE                         2
# 9511  Actavis Pharma, Inc.   NATEGLINIDE                        60
# 9512  Actavis Pharma, Inc.   NATEGLINIDE                       120
#
#      ACTIVE_INGRED_UNIT                                      PHARM_CLASSES  \
# 9329               mg/1  Glinide [EPC], Potassium Channel Antagonists [...
# 9330               mg/1  Glinide [EPC], Potassium Channel Antagonists [...
# 9331               mg/1  Glinide [EPC], Potassium Channel Antagonists [...
# 9511               mg/1  Glinide [EPC], Potassium Channel Antagonists [...
# 9512               mg/1  Glinide [EPC], Potassium Channel Antagonists [...
#
#      DEASCHEDULE NDC_EXCLUDE_FLAG  LISTING_RECORD_CERTIFIED_THROUGH
# 9329         NaN                N                        20241231.0
# 9330         NaN                N                               NaN
# 9331         NaN                N                               NaN
# 9511         NaN                N                        20241231.0
# 9512         NaN                N                        20241231.0

# %% [markdown]
# ### Dipeptidyl peptidase-4 (DPP-4) inhibitors
# DPP-4 inhibitors are used to help reduce blood sugar without causing hypoglycemia.
#
# DPP-4 inhibitors blockTrusted Source the DPP-4 enzyme. This enzyme destroys a hormone called incretin, which normally helps your body produce insulin when it’s needed. Incretins also decrease glucose output from the liver when your body doesn’t need it.

# %%
DDP_4_INHB=product_df[product_df['PHARM_CLASSES'].str.contains('Dipeptidyl Peptidase 4 Inhibitor', case=False, na=False)]
DDP_4_INHB.head(5)
# Out:
#                                           PRODUCTID PRODUCTNDC  \
# 179  0006-0078_40b87f24-8005-4ee7-b162-94690443fdb0  0006-0078
# 180  0006-0080_40b87f24-8005-4ee7-b162-94690443fdb0  0006-0080
# 181  0006-0081_40b87f24-8005-4ee7-b162-94690443fdb0  0006-0081
# 182  0006-0112_6970c5e9-bd40-4847-9321-ab5826b7b7e5  0006-0112
# 183  0006-0221_6970c5e9-bd40-4847-9321-ab5826b7b7e5  0006-0221
#
#              PRODUCTTYPENAME PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 179  HUMAN PRESCRIPTION DRUG         JANUMET                    XR
# 180  HUMAN PRESCRIPTION DRUG         JANUMET                    XR
# 181  HUMAN PRESCRIPTION DRUG         JANUMET                    XR
# 182  HUMAN PRESCRIPTION DRUG         JANUVIA                   NaN
# 183  HUMAN PRESCRIPTION DRUG         JANUVIA                   NaN
#
#                           NONPROPRIETARYNAME  \
# 179  sitagliptin and metformin hydrochloride
# 180  sitagliptin and metformin hydrochloride
# 181  sitagliptin and metformin hydrochloride
# 182                              sitagliptin
# 183                              sitagliptin
#
#                             DOSAGEFORMNAME ROUTENAME  STARTMARKETINGDATE  \
# 179  TABLET, FILM COATED, EXTENDED RELEASE      ORAL            20120202
# 180  TABLET, FILM COATED, EXTENDED RELEASE      ORAL            20120202
# 181  TABLET, FILM COATED, EXTENDED RELEASE      ORAL            20120202
# 182                    TABLET, FILM COATED      ORAL            20061016
# 183                    TABLET, FILM COATED      ORAL            20061016
#
#      ENDMARKETINGDATE MARKETINGCATEGORYNAME APPLICATIONNUMBER  \
# 179               NaN                   NDA         NDA202270
# 180               NaN                   NDA         NDA202270
# 181               NaN                   NDA         NDA202270
# 182               NaN                   NDA         NDA021995
# 183               NaN                   NDA         NDA021995
#
#                  LABELERNAME                                   SUBSTANCENAME  \
# 179  Merck Sharp & Dohme LLC  METFORMIN HYDROCHLORIDE; SITAGLIPTIN PHOSPHATE
# 180  Merck Sharp & Dohme LLC  METFORMIN HYDROCHLORIDE; SITAGLIPTIN PHOSPHATE
# 181  Merck Sharp & Dohme LLC  METFORMIN HYDROCHLORIDE; SITAGLIPTIN PHOSPHATE
# 182  Merck Sharp & Dohme LLC                           SITAGLIPTIN PHOSPHATE
# 183  Merck Sharp & Dohme LLC                           SITAGLIPTIN PHOSPHATE
#
#     ACTIVE_NUMERATOR_STRENGTH ACTIVE_INGRED_UNIT  \
# 179                   500; 50         mg/1; mg/1
# 180                  1000; 50         mg/1; mg/1
# 181                 1000; 100         mg/1; mg/1
# 182                        50               mg/1
# 183                        25               mg/1
#
#                                          PHARM_CLASSES DEASCHEDULE  \
# 179  Biguanide [EPC], Biguanides [CS], Dipeptidyl P...         NaN
# 180  Biguanide [EPC], Biguanides [CS], Dipeptidyl P...         NaN
# 181  Biguanide [EPC], Biguanides [CS], Dipeptidyl P...         NaN
# 182  Dipeptidyl Peptidase 4 Inhibitor [EPC], Dipept...         NaN
# 183  Dipeptidyl Peptidase 4 Inhibitor [EPC], Dipept...         NaN
#
#     NDC_EXCLUDE_FLAG  LISTING_RECORD_CERTIFIED_THROUGH
# 179                N                        20241231.0
# 180                N                        20241231.0
# 181                N                        20241231.0
# 182                N                        20241231.0
# 183                N                        20241231.0

# %% [markdown]
# ### Group them together into one file

# %%
grp = [Insulin, Thiazolidinedione, Sulfonylurea,SGLT_2_INHB,Glinide,GLP_1_RA,DDP_4_INHB,DA_2A,Biguanides,Alpha_G_INHB]

# %%
DB_Grp = pd.concat(grp, ignore_index=True).drop_duplicates()

# %%
DB_Grp.head(5)
# Out:
#                                         PRODUCTID PRODUCTNDC  \
# 0  0002-0213_458ef2aa-cd5f-48bc-8829-82420cfed33b  0002-0213
# 1  0002-1152_a820004b-8342-4e58-b733-2d97445b2f5e  0002-1152
# 2  0002-1243_a820004b-8342-4e58-b733-2d97445b2f5e  0002-1243
# 3  0002-1457_a820004b-8342-4e58-b733-2d97445b2f5e  0002-1457
# 4  0002-1460_a820004b-8342-4e58-b733-2d97445b2f5e  0002-1460
#
#            PRODUCTTYPENAME PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 0           HUMAN OTC DRUG         Humulin                     R
# 1  HUMAN PRESCRIPTION DRUG        MOUNJARO                   NaN
# 2  HUMAN PRESCRIPTION DRUG        MOUNJARO                   NaN
# 3  HUMAN PRESCRIPTION DRUG        MOUNJARO                   NaN
# 4  HUMAN PRESCRIPTION DRUG        MOUNJARO                   NaN
#
#   NONPROPRIETARYNAME       DOSAGEFORMNAME     ROUTENAME  STARTMARKETINGDATE  \
# 0      Insulin human  INJECTION, SOLUTION    PARENTERAL            19830627
# 1        tirzepatide  INJECTION, SOLUTION  SUBCUTANEOUS            20230728
# 2        tirzepatide  INJECTION, SOLUTION  SUBCUTANEOUS            20230728
# 3        tirzepatide  INJECTION, SOLUTION  SUBCUTANEOUS            20220513
# 4        tirzepatide  INJECTION, SOLUTION  SUBCUTANEOUS            20220513
#
#    ENDMARKETINGDATE MARKETINGCATEGORYNAME APPLICATIONNUMBER  \
# 0               NaN                   BLA         BLA018780
# 1               NaN                   NDA         NDA215866
# 2               NaN                   NDA         NDA215866
# 3               NaN                   NDA         NDA215866
# 4               NaN                   NDA         NDA215866
#
#              LABELERNAME  SUBSTANCENAME ACTIVE_NUMERATOR_STRENGTH  \
# 0  Eli Lilly and Company  INSULIN HUMAN                       100
# 1  Eli Lilly and Company    TIRZEPATIDE                       2.5
# 2  Eli Lilly and Company    TIRZEPATIDE                         5
# 3  Eli Lilly and Company    TIRZEPATIDE                        15
# 4  Eli Lilly and Company    TIRZEPATIDE                      12.5
#
#   ACTIVE_INGRED_UNIT                                      PHARM_CLASSES  \
# 0            [iU]/mL                        Insulin [CS], Insulin [EPC]
# 1            mg/.5mL  G-Protein-linked Receptor Interactions [MoA], ...
# 2            mg/.5mL  G-Protein-linked Receptor Interactions [MoA], ...
# 3            mg/.5mL  G-Protein-linked Receptor Interactions [MoA], ...
# 4            mg/.5mL  G-Protein-linked Receptor Interactions [MoA], ...
#
#   DEASCHEDULE NDC_EXCLUDE_FLAG  LISTING_RECORD_CERTIFIED_THROUGH
# 0         NaN                N                        20241231.0
# 1         NaN                N                        20241231.0
# 2         NaN                N                        20241231.0
# 3         NaN                N                        20241231.0
# 4         NaN                N                        20241231.0

# %% [markdown]
# ### Attach Product Package NDC from package_df
# We alos add the field of package description in case the subsequent analysis may need.

# %%
DB_Grp_NDC=pd.merge(DB_Grp, package_df[['PRODUCTID', 'NDCPACKAGECODE','PACKAGEDESCRIPTION']], on='PRODUCTID', how='left')

# %%
DB_Grp_NDC.head(5)
# Out:
#                                         PRODUCTID PRODUCTNDC  \
# 0  0002-0213_458ef2aa-cd5f-48bc-8829-82420cfed33b  0002-0213
# 1  0002-1152_a820004b-8342-4e58-b733-2d97445b2f5e  0002-1152
# 2  0002-1243_a820004b-8342-4e58-b733-2d97445b2f5e  0002-1243
# 3  0002-1457_a820004b-8342-4e58-b733-2d97445b2f5e  0002-1457
# 4  0002-1460_a820004b-8342-4e58-b733-2d97445b2f5e  0002-1460
#
#            PRODUCTTYPENAME PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 0           HUMAN OTC DRUG         Humulin                     R
# 1  HUMAN PRESCRIPTION DRUG        MOUNJARO                   NaN
# 2  HUMAN PRESCRIPTION DRUG        MOUNJARO                   NaN
# 3  HUMAN PRESCRIPTION DRUG        MOUNJARO                   NaN
# 4  HUMAN PRESCRIPTION DRUG        MOUNJARO                   NaN
#
#   NONPROPRIETARYNAME       DOSAGEFORMNAME     ROUTENAME  STARTMARKETINGDATE  \
# 0      Insulin human  INJECTION, SOLUTION    PARENTERAL            19830627
# 1        tirzepatide  INJECTION, SOLUTION  SUBCUTANEOUS            20230728
# 2        tirzepatide  INJECTION, SOLUTION  SUBCUTANEOUS            20230728
# 3        tirzepatide  INJECTION, SOLUTION  SUBCUTANEOUS            20220513
# 4        tirzepatide  INJECTION, SOLUTION  SUBCUTANEOUS            20220513
#
#    ENDMARKETINGDATE  ...            LABELERNAME  SUBSTANCENAME  \
# 0               NaN  ...  Eli Lilly and Company  INSULIN HUMAN
# 1               NaN  ...  Eli Lilly and Company    TIRZEPATIDE
# 2               NaN  ...  Eli Lilly and Company    TIRZEPATIDE
# 3               NaN  ...  Eli Lilly and Company    TIRZEPATIDE
# 4               NaN  ...  Eli Lilly and Company    TIRZEPATIDE
#
#   ACTIVE_NUMERATOR_STRENGTH ACTIVE_INGRED_UNIT  \
# 0                       100            [iU]/mL
# 1                       2.5            mg/.5mL
# 2                         5            mg/.5mL
# 3                        15            mg/.5mL
# 4                      12.5            mg/.5mL
#
#                                        PHARM_CLASSES DEASCHEDULE  \
# 0                        Insulin [CS], Insulin [EPC]         NaN
# 1  G-Protein-linked Receptor Interactions [MoA], ...         NaN
# 2  G-Protein-linked Receptor Interactions [MoA], ...         NaN
# 3  G-Protein-linked Receptor Interactions [MoA], ...         NaN
# 4  G-Protein-linked Receptor Interactions [MoA], ...         NaN
#
#   NDC_EXCLUDE_FLAG LISTING_RECORD_CERTIFIED_THROUGH NDCPACKAGECODE  \
# 0                N                       20241231.0   0002-0213-01
# 1                N                       20241231.0   0002-1152-01
# 2                N                       20241231.0   0002-1243-01
# 3                N                       20241231.0   0002-1457-80
# 4                N                       20241231.0   0002-1460-80
#
#                                   PACKAGEDESCRIPTION
# 0  1 VIAL, MULTI-DOSE in 1 CARTON (0002-0213-01) ...
# 1  1 VIAL, SINGLE-DOSE in 1 CARTON (0002-1152-01)...
# 2  1 VIAL, SINGLE-DOSE in 1 CARTON (0002-1243-01)...
# 3  4 SYRINGE in 1 CARTON (0002-1457-80)  / .5 mL ...
# 4  4 SYRINGE in 1 CARTON (0002-1460-80)  / .5 mL ...
#
# [5 rows x 22 columns]

# %%
#DB_Grp_NDC.to_excel(r'C:\Users\syuan\OneDrive - Fresenius\Desktop\ITS\Python Files\DP_File_Check.xlsx',sheet_name='DC')

# %%
### Check and clean
len(DB_Grp_NDC)
# Out:
# 3336

# %%
### check the count of unmatched codes (sometimes, the code is disontinued, it wont have NDC package code)
empty_ndc_count = DB_Grp_NDC['NDCPACKAGECODE'].isnull().sum()
empty_ndc_count
# Out:
# 1

# %%
DB_GRP = DB_Grp_NDC.dropna(subset=['NDCPACKAGECODE'], how='any')

# %%
len(DB_GRP)
# Out:
# 3335
